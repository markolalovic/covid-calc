# %%
import pandas as pd

# %%
language = 'spanish'
app = pd.read_csv('data/translations/english_' + language + '_app.csv')

# %%
app
# Out:
#                                               english  \
# 0                              Coronavirus Calculator
# 1                                            Location
# 2                                     Select location
# 3                          How COVID-19 Compare With
# 4                                       Select source
# ..                                                ...
# 94                                  Diet high in salt
# 95                                High blood pressure
# 96                              Low physical activity
# 97                   Air pollution (outdoor & indoor)
# 98  A visual tool to explore and analyze potential...
#
#                                               spanish  \
# 0                          Calculadora de coronavirus
# 1                                           Ubicación
# 2                                Seleccione ubicación
# 3                        Cómo se compara COVID-19 con
# ...

# %%
english_english = pd.read_csv('data/translations/english_english_app.csv')

# %%
english_english
# Out:
#                                               english  \
# 0                              Coronavirus Calculator
# 1   A visual tool to explore and analyze potential...
# 2                                            Location
# 3                                     Select location
# 4                          How COVID-19 Compare With
# ..                                                ...
# 94                                           Drug use
# 95                        COVID-19 until May 27, 2020
# 96                                            Smoking
# 97                                   Secondhand smoke
# 98                        Non-exclusive breastfeeding
#
#                                               chinese  \
# 0                                 translated saldkfj;
# 1   A visual tool to explore and analyze potential...
# 2                                            Location
# 3                                     Select location
# ...

# %%
english_english.iloc[0]['english']
# Out:
# 'Coronavirus Calculator'

# %%
english_english.iloc[0][language] = 'translated saldkfj;'

# %%
english_english.rename(columns={'target': 'chinese'}, inplace=True)
